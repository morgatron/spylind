# %% [markdown]
# # Propagation in birefingent materials

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from pylab import *
import sympy as sm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
k00.expand?
# Out:
# Signature:
# k00.expand(
#     deep=True,
#     modulus=None,
#     power_base=True,
#     power_exp=True,
#     mul=True,
#     log=True,
#     multinomial=True,
#     basic=True,
#     **hints,
# )
# Docstring:
# Expand an expression using hints.
#
# See the docstring of the expand() function in sympy.core.function for
# more information.
# File:      ~/miniforge3/envs/spylind/lib/python3.8/site-packages/sympy/core/expr.py
# Type:      method

# %%
z = sm.symbols('z', real=True)
k00,k01,k10,k11 = sm.symbols('k00, k01, k10, k11', complex=True)
Ex, Ey = sm.symbols("Ex, Ey", complex=True)
E = sm.Matrix([[Ex], [Ey]])
ex=sm.exp(sm.I*sm.Matrix([[k00,k01], [k10, k11]])*z)*E

# %%
ex.subs({z:0,  k01:0, k10:0})
# Out:
# Matrix([
# [ 0],
# [Ey]])

# %%
f=sm.lambdify([z, k00,k01,k10,k11, Ex, Ey], ex)

# %%
f(0, 1.,0.,0.,1.,1.,0.)
# Out:
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in cdouble_scalars
# ...

# %%
z = linspace(0,10,1000)

# %%
kappa =sm.MatrixSymbol('kappa', 2,2)
kappa = kappa.as_explicit()
sm.exp(kappa)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/sympy/core/function.py in __new__(cls, *args, **options)
#     284         if evaluate:
# --> 285             evaluated = cls.eval(*args)
#     286             if evaluated is not None:
#
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/sympy/functions/elementary/exponential.py in eval(cls, arg)
#     272         if isinstance(arg, MatrixBase):
# --> 273             return arg.exp()
#     274         elif global_parameters.exp_is_pow:
#
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/sympy/matrices/matrices.py in exp(self)
# ...

# %%
k00 = 1
k11 = 0
k01 = 0.
k10 = np.conj(k01)
kappa = np.matrix([[k00, k01], [k10, k11]])
kappa
# Out:
# matrix([[1., 0.],
#         [0., 0.]])

# %%
sm

# %%
from numpy import matrixlib
matrixlib.e

# %%
E0 = np.matrix([[1matrix_power+ 0.j]])
E0
# Out:
# matrix([[1.+0.j],
#         [0.+0.j]])

# %%
np.exp(1j*kappa*0.001)
# Out:
# matrix([[0.9999995+0.001j, 1.       +0.j   ],
#         [1.       +0.j   , 1.       +0.j   ]])

# %%
z[newaxis,newaxis,:].shape
# Out:
# (1, 1, 100)

# %%
kappa[:,:,newaxis].shape
# Out:
# (2, 2, 1)

# %%
# Out:
# matrix([[0.9999995+0.001j, 1.       +0.j   ],
#         [1.       +0.j   , 0.9999995+0.001j]])

# %%
Ez = np.array([kappa*z*E0 for z in linspace(0,2,100)])
plot(abs(Ez).squeeze().real)
#plot(Ez.squeeze().imag)

# %%
np.exp(1j*kappa[:]*z[newaxis]).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-4dbf1b9518b1> in <module>
# ----> 1 np.exp(1j*kappa[:]*z[newaxis]).shape
#
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/numpy/matrixlib/defmatrix.py in __mul__(self, other)
#     216         if isinstance(other, (N.ndarray, list, tuple)) :
#     217             # This promotes 1-D vectors to row vectors
# --> 218             return N.dot(self, asmatrix(other))
#     219         if isscalar(other) or not hasattr(other, '__rmul__') :
#     220             return N.dot(self, other)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (1,100) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
z = linspace(0,1,100)
np.exp(1j*kappa*z)*E
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-d0429c21c5e6> in <module>
#       1 z = linspace(0,1,100)
# ----> 2 np.exp(1j*kappa*z)*E
#
# ~/miniforge3/envs/spylind/lib/python3.8/site-packages/numpy/matrixlib/defmatrix.py in __mul__(self, other)
#     216         if isinstance(other, (N.ndarray, list, tuple)) :
#     217             # This promotes 1-D vectors to row vectors
# --> 218             return N.dot(self, asmatrix(other))
#     219         if isscalar(other) or not hasattr(other, '__rmul__') :
#     220             return N.dot(self, other)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (1,100) not aligned: 2 (dim 1) != 1 (dim 0)

# %%
kappa = sm.Matrix([])

# %%
kappa = np.matrix([[]])

# %%
E = exp(1j*kappa*z)
