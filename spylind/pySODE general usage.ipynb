# %% [markdown]
# # What is it?
# pySODE is in principle YET ANOTHER(!!) a generalish-purpose nnumerical IVP solver with some symbollic elements. It has a lot of overlap with Mathematica's NDSolve- NDSolve obviously is way more powerful for solving general equations (including PDEs).  But symODE is good for a range of useful problems, and has (or will have) a few features that aren't easily reproduced in Mathematics.  Overall it is less of a 'black-box than NDSolve, for better or worse.
#
# 1. Can easily add explicit numerical code ( can in Mathematica too, but more hoops)
# 2. Can (shortly) integrate with tensorflow, bot for increased speed and to enable automatic differentiation.
# 3. The driving use case is ensembles of similar atoms interacting by long-range electric fields: large ensembles of states with long-range coupling
#
# Other python ODE solving packages that are likely more approtriate for general use:
#
# * https://github.com/neurophysik/jitcode,
# * http://bjodah.github.io/pyodesys/latest/index.html
#
# They both seem more powerful, could likely replace this package for even the desired purpose. However I only learned about them after writing this, and I haven't tried them. To my mind it does seem unlikely that they'll be easily extended to large scales or to automatic differentiation of the whole system as is possible with Tensorflow, but please let me know if I"m mistaken
#
#
# # Example general usage
#
# Mostly what it's written for though is to enable assembling/solving master-equation based systems in python. That will be covered in [Solving master equations using pySODE]

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from pylab import *|
import symODE as so
import sympy as sm
sm.init_printing()
# Out:
#   File "<ipython-input-9-b7a08e8c44fb>", line 4
#     from pylab import *|
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Projectile motion
#
# dx/dt = vx
# dy/dt = vy
#
# dvx/dt = g
# dvy/dt = 0

# %%
xS, yS, vxS, vyS = sm.symbols("x, y, v_x, v_y", real=True)
g= -10.0
dy_dtD = {xS:vxS, 
       yS:vyS,
       vxS:1,
       vyS:g }

# %%
ode_s = so.ODESolver(dy_dtD,  dims={})
ode_s.set_initial_conditions({xS:0,yS:0,vxS:10,vyS:10}) 
ode_s.setup()
tSteps = linspace(0,1,100)
arr =ode_s.integrate(tSteps, 1.0)

plot(tSteps, arr)
xlabel('t')
legend(dy_dtD.keys())
# Out:
# Munch({'tSym': t, 'dimSyms': [], 'prop_state_syms': [x, y, v_x, v_y], 'stationary_state_syms': [], 'driving_syms': [], 'state_dep_syms': []})
# state dependent functions should have signature [t, x, y, v_x, v_y]
# C:\Users\morgan\Anaconda3\envs\pymbe\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## An ensemble of similar projectiles

# %%
xS, yS, vxS, vyS = sm.symbols("x, y, v_x, v_y", real=True)
zS = sm.symbols("z", real=True)
g= -10.0
dy_dtD = {xS:vxS, 
       yS:vyS,
       vxS:1 +zS,
       vyS: g  }

ode_s = so.ODESolver(dy_dtD,  dims={zS:linspace(-2,2,10)})
ode_s.set_initial_conditions({xS:0,yS:0,vxS:10,vyS:10}) 
ode_s.setup()
tSteps = linspace(0,1,100)
arr =ode_s.integrate(tSteps, 1.0)

plot(tSteps, arr[:,:,0].real)
xlabel('t')
legend(dy_dtD.keys())
figure()
plot(tSteps, arr[:,:,-1].real)
xlabel('t')
legend(dy_dtD.keys())
figure()
imshow(arr[:,1,:].real, aspect='auto')
# Out:
# Munch({'tSym': t, 'dimSyms': [z], 'prop_state_syms': [x, y, v_x, v_y], 'stationary_state_syms': [], 'driving_syms': [], 'state_dep_syms': [z]})
# state dependent functions should have signature [t, z, x, y, v_x, v_y]
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# <ipython-input-57-a8e6fff18ff6> in <module>
#      11 ode_s.setup()
#      12 tSteps = linspace(0,1,100)
# ---> 13 arr =ode_s.integrate(tSteps, 1.0)
#      14
#      15 plot(tSteps, arr[:,:,0].real)
#
# ~\Documents\pySODE\symODE.py in integrate(self, tSteps, max_step_size, atol, rtol)
#     562                     print("Integration failed at sim time {}".format(tNext))
#     563                     break;
# --> 564                 cur = r.integrate(tNext)
#     565                 self._online_process_func(cur) #probably reshaping, calculating fields etc
#     566                 #print('.',end='', flush=True)
#
# ~\Anaconda3\envs\pymbe\lib\site-packages\scipy\integrate\_ode.py in integrate(self, t, step, relax)
#     428
#     429         try:
# --> 430             self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     431                                   self._y, self.t, t,
#     432                                   self.f_params, self.jac_params)
#
# ~\Anaconda3\envs\pymbe\lib\site-packages\scipy\integrate\_ode.py in run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1002         args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1003                 (f_params, jac_params))
# -> 1004         y1, t, istate = self.runner(*args)
#    1005         self.istate = istate
#    1006         if istate < 0:
#
# ~\Documents\pySODE\symODE.py in dy_dt(t, cur_state_flat, dimAxes, Npars, state_shape, d_dt_prealloc, d_dtF, flatten, unflatten, state_dep_f, t_dep_f)
#     500                     #pdb.set_trace()
#     501                 state_dep_vals = [f(t, dimAxes, state, driving_vals) for f in state_dep_f]
# --> 502                 d_dt_prealloc[:] =  d_dtF(t, *dimAxes, *state, *driving_vals, *state_dep_vals)
#     503                 return flatten(d_dt_prealloc)
#     504         else: #Tensorflow it...
#
# ValueError: could not broadcast input array from shape (4) into shape (4,10)

# %% [markdown]
# ## An ensemble of interacting projectiles (via a mutual attraction)

# %%
xS, yS, vxS, vyS, kS = sm.symbols("x, y, v_x, v_y, k", real=True)
zS = sm.symbols("z", real=True)
g= -10.0
dy_dtD = {xS:vxS, 
       yS:vyS,
       vxS:1,
       vyS: g + 30*kS }

ode_s = so.ODESolver(dy_dtD,  dims={zS:linspace(-2,2,10)})
ode_s.set_initial_conditions({xS:0*ones(10),yS:linspace(-3,3,10),vxS:10*ones(10),vyS:10*ones(10) }) 
def couplingF(t, dimAxes, state, driving_vals):
    x,y,vx,vy = state
    return y.mean()-y
ode_s.set_state_dep_funcs({kS:couplingF})

ode_s.setup()
tSteps = linspace(0,3,1000)
arr =ode_s.integrate(tSteps, 1.0)

plot(tSteps, arr[:,1,:].real)
xlabel('t')
ylabel('y')
# Out:
# Munch({'tSym': t, 'dimSyms': [z], 'prop_state_syms': [x, y, v_x, v_y], 'stationary_state_syms': [], 'driving_syms': [], 'state_dep_syms': [k]})
# state dependent functions should have signature [t, z, x, y, v_x, v_y]
# Text(0, 0.5, 'y')

# %% [markdown]
# ## pyODEsys

# %%
from pyodesys.symbolic import SymbolicSys
def f(t, y, p):
    return [y[1], -y[0] + p[0]*y[1]*(1 - y[0]**2)]

odesys = SymbolicSys.from_callback(f, 2, 1)
xout, yout, info = odesys.integrate(10, [1, 0], [1], integrator='cvode', nsteps=1000)
_ = odesys.plot_result()
import matplotlib.pyplot as plt; plt.show()
# Out:
# ------------------------------------------------------------
# ModuleNotFoundError        Traceback (most recent call last)
# <ipython-input-64-53fba5f23741> in <module>
#       4
#       5 odesys = SymbolicSys.from_callback(f, 2, 1)
# ----> 6 xout, yout, info = odesys.integrate(10, [1, 0], [1], integrator='cvode', nsteps=1000)
#       7 _ = odesys.plot_result()
#       8 import matplotlib.pyplot as plt; plt.show()
#
# ~\Anaconda3\envs\pymbe\lib\site-packages\pyodesys\core.py in integrate(self, x, y0, params, atol, rtol, **kwargs)
#     428         self._current_integration_kwargs = kwargs
#     429         if isinstance(integrator, str):
# --> 430             nfo = getattr(self, '_integrate_' + integrator)(*args, **kwargs)
#     431         else:
#     432             kwargs['with_jacobian'] = getattr(integrator, 'with_jacobian', None)
#
# ~\Anaconda3\envs\pymbe\lib\site-packages\pyodesys\core.py in _integrate_cvode(self, *args, **kwargs)
#     712         (via `pycvodes <https://pypi.python.org/pypi/pycvodes>`_)
#     713         to integrate the ODE system. """
# --> 714         import pycvodes  # Python interface to SUNDIALS's cvodes integrators
#     715         kwargs['with_jacobian'] = kwargs.get('method', 'bdf') in pycvodes.requires_jac
#     716         if 'lband' in kwargs or 'uband' in kwargs or 'band' in kwargs:
#
# ModuleNotFoundError: No module named 'pycvodes'

# %%
>>> odesys = SymbolicSys.from_callback(
...     lambda x, y, p: [
...         -p[0]*y[0],
...         p[0]*y[0] - p[1]*y[1]
...     ], 2, 2)
>>> dep0 = odesys.dep[0]
>>> partsys = PartiallySolvedSystem(odesys, lambda x0, y0, p0, be: {
...         dep0: y0[0]*be.exp(-p0[0]*(odesys.indep-x0))
...     })
>>> print(partsys.exprs)  
(_Dummy_29*p_0*exp(-p_0*(-_Dummy_28 + x)) - p_1*y_1,)
>>> y0, k = [3, 2], [3.5, 2.5]
>>> xout, yout, info = partsys.integrate([0, 1], y0, k, integrator='cvode')
>>> info['success'], yout.shape[1]
(True, 2)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-63-777d89ccef0d> in <module>
#       5     ], 2, 2)
#       6 dep0 = odesys.dep[0]
# ----> 7 partsys = PartiallySolvedSystem(odesys, lambda x0, y0, p0, be: {
#       8         dep0: y0[0]*be.exp(-p0[0]*(odesys.indep-x0))
#       9     })
#
# NameError: name 'PartiallySolvedSystem' is not defined
